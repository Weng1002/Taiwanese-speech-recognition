# %%
pip install librosa pandas torch torchaudio transformers tqdm numpy

# %%
import os
import subprocess

def convert_audio(input_dir, output_dir):
    # 確保輸出目錄存在
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # 遍歷目錄中的所有 .wav 文件
    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.endswith(".wav"):
                input_path = os.path.join(root, file)
                
                # 生成輸出文件的路徑
                relative_path = os.path.relpath(root, input_dir)  # 保留相對路徑
                output_folder = os.path.join(output_dir, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)
                
                output_path = os.path.join(output_folder, file)
                
                # 調用 Sox 進行格式轉換
                command = [
                    "sox", input_path,
                    "-r", "16000",         # 16 kHz
                    "-e", "signed-integer",# signed-integer
                    "-b", "16",            # 16 bits
                    output_path
                ]
                
                print(f"Converting: {input_path} -> {output_path}")
                subprocess.run(command, check=True)

# 設置資料夾
train_input_dir = "train"
train_output_dir = "train_converted"
test_input_dir = "test"
test_output_dir = "test_converted"

# 轉換 train 和 test 資料夾中的音頻
convert_audio(train_input_dir, train_output_dir)
convert_audio(test_input_dir, test_output_dir)
# Out:
# Converting: train/2392.wav -> train_converted/./2392.wav
# Converting: train/1314.wav -> train_converted/./1314.wav
# Converting: train/1026.wav -> train_converted/./1026.wav
# Converting: train/1142.wav -> train_converted/./1142.wav
# Converting: train/1802.wav -> train_converted/./1802.wav
# Converting: train/148.wav -> train_converted/./148.wav
# Converting: train/1098.wav -> train_converted/./1098.wav
# Converting: train/2077.wav -> train_converted/./2077.wav
# Converting: train/1367.wav -> train_converted/./1367.wav
# Converting: train/3087.wav -> train_converted/./3087.wav
# Converting: train/1385.wav -> train_converted/./1385.wav
# Converting: train/1018.wav -> train_converted/./1018.wav
# Converting: train/1784.wav -> train_converted/./1784.wav
# Converting: train/2966.wav -> train_converted/./2966.wav
# Converting: train/340.wav -> train_converted/./340.wav
# Converting: train/2414.wav -> train_converted/./2414.wav
# Converting: train/1256.wav -> train_converted/./1256.wav
# Converting: train/1188.wav -> train_converted/./1188.wav
# Converting: train/2778.wav -> train_converted/./2778.wav
# Converting: train/209.wav -> train_converted/./209.wav
# Converting: train/270.wav -> train_converted/./270.wav
# Converting: train/2139.wav -> train_converted/./2139.wav
# Converting: train/1081.wav -> train_converted/./1081.wav
# Converting: train/2224.wav -> train_converted/./2224.wav
# Converting: train/2442.wav -> train_converted/./2442.wav
# Converting: train/278.wav -> train_converted/./278.wav
# Converting: train/2579.wav -> train_converted/./2579.wav
# Converting: train/977.wav -> train_converted/./977.wav
# Converting: train/1668.wav -> train_converted/./1668.wav
# Converting: train/1193.wav -> train_converted/./1193.wav
# Converting: train/2365.wav -> train_converted/./2365.wav
# Converting: train/1755.wav -> train_converted/./1755.wav
# Converting: train/1839.wav -> train_converted/./1839.wav
# Converting: train/1968.wav -> train_converted/./1968.wav
# Converting: train/665.wav -> train_converted/./665.wav
# Converting: train/1945.wav -> train_converted/./1945.wav
# Converting: train/510.wav -> train_converted/./510.wav
# Converting: train/1877.wav -> train_converted/./1877.wav
# Converting: train/389.wav -> train_converted/./389.wav
# Converting: train/2256.wav -> train_converted/./2256.wav
# Converting: train/2892.wav -> train_converted/./2892.wav
# Converting: train/917.wav -> train_converted/./917.wav
# Converting: train/603.wav -> train_converted/./603.wav
# Converting: train/1674.wav -> train_converted/./1674.wav
# Converting: train/32.wav -> train_converted/./32.wav
# Converting: train/2074.wav -> train_converted/./2074.wav
# Converting: train/891.wav -> train_converted/./891.wav
# Converting: train/2700.wav -> train_converted/./2700.wav
# Converting: train/4.wav -> train_converted/./4.wav
# Converting: train/3020.wav -> train_converted/./3020.wav
# Converting: train/2915.wav -> train_converted/./2915.wav
# Converting: train/2581.wav -> train_converted/./2581.wav
# Converting: train/2241.wav -> train_converted/./2241.wav
# Converting: train/1443.wav -> train_converted/./1443.wav
# Converting: train/2271.wav -> train_converted/./2271.wav
# Converting: train/372.wav -> train_converted/./372.wav
# Converting: train/1169.wav -> train_converted/./1169.wav
# Converting: train/2882.wav -> train_converted/./2882.wav
# Converting: train/2674.wav -> train_converted/./2674.wav
# Converting: train/2811.wav -> train_converted/./2811.wav
# Converting: train/435.wav -> train_converted/./435.wav
# Converting: train/2659.wav -> train_converted/./2659.wav
# Converting: train/1383.wav -> train_converted/./1383.wav
# Converting: train/185.wav -> train_converted/./185.wav
# Converting: train/649.wav -> train_converted/./649.wav
# Converting: train/844.wav -> train_converted/./844.wav
# Converting: train/2433.wav -> train_converted/./2433.wav
# Converting: train/2991.wav -> train_converted/./2991.wav
# Converting: train/2035.wav -> train_converted/./2035.wav
# Converting: train/1395.wav -> train_converted/./1395.wav
# Converting: train/260.wav -> train_converted/./260.wav
# Converting: train/161.wav -> train_converted/./161.wav
# Converting: train/529.wav -> train_converted/./529.wav
# Converting: train/1362.wav -> train_converted/./1362.wav
# Converting: train/1057.wav -> train_converted/./1057.wav
# Converting: train/1916.wav -> train_converted/./1916.wav
# Converting: train/1494.wav -> train_converted/./1494.wav
# Converting: train/2200.wav -> train_converted/./2200.wav
# Converting: train/2603.wav -> train_converted/./2603.wav
# Converting: train/800.wav -> train_converted/./800.wav
# Converting: train/1787.wav -> train_converted/./1787.wav
# Converting: train/1943.wav -> train_converted/./1943.wav
# Converting: train/2802.wav -> train_converted/./2802.wav
# Converting: train/1718.wav -> train_converted/./1718.wav
# Converting: train/2699.wav -> train_converted/./2699.wav
# Converting: train/1135.wav -> train_converted/./1135.wav
# Converting: train/165.wav -> train_converted/./165.wav
# Converting: train/2319.wav -> train_converted/./2319.wav
# Converting: train/2996.wav -> train_converted/./2996.wav
# Converting: train/887.wav -> train_converted/./887.wav
# Converting: train/1607.wav -> train_converted/./1607.wav
# Converting: train/2007.wav -> train_converted/./2007.wav
# Converting: train/1725.wav -> train_converted/./1725.wav
# Converting: train/1489.wav -> train_converted/./1489.wav
# Converting: train/1353.wav -> train_converted/./1353.wav
# Converting: train/1519.wav -> train_converted/./1519.wav
# Converting: train/816.wav -> train_converted/./816.wav
# Converting: train/609.wav -> train_converted/./609.wav
# Converting: train/2914.wav -> train_converted/./2914.wav
# Converting: train/1088.wav -> train_converted/./1088.wav
# Converting: train/138.wav -> train_converted/./138.wav
# Converting: train/801.wav -> train_converted/./801.wav
# Converting: train/2843.wav -> train_converted/./2843.wav
# Converting: train/2128.wav -> train_converted/./2128.wav
# Converting: train/44.wav -> train_converted/./44.wav
# Converting: train/946.wav -> train_converted/./946.wav
# Converting: train/2216.wav -> train_converted/./2216.wav
# Converting: train/2766.wav -> train_converted/./2766.wav
# Converting: train/724.wav -> train_converted/./724.wav
# Converting: train/900.wav -> train_converted/./900.wav
# Converting: train/576.wav -> train_converted/./576.wav
# Converting: train/390.wav -> train_converted/./390.wav
# Converting: train/596.wav -> train_converted/./596.wav
# Converting: train/2986.wav -> train_converted/./2986.wav
# Converting: train/181.wav -> train_converted/./181.wav
# Converting: train/355.wav -> train_converted/./355.wav
# Converting: train/2260.wav -> train_converted/./2260.wav
# Converting: train/848.wav -> train_converted/./848.wav
# Converting: train/842.wav -> train_converted/./842.wav
# Converting: train/2748.wav -> train_converted/./2748.wav
# Converting: train/546.wav -> train_converted/./546.wav
# Converting: train/1306.wav -> train_converted/./1306.wav
# Converting: train/1633.wav -> train_converted/./1633.wav
# Converting: train/18.wav -> train_converted/./18.wav
# Converting: train/939.wav -> train_converted/./939.wav
# Converting: train/897.wav -> train_converted/./897.wav
# Converting: train/1221.wav -> train_converted/./1221.wav
# Converting: train/6.wav -> train_converted/./6.wav
# Converting: train/1660.wav -> train_converted/./1660.wav
# Converting: train/703.wav -> train_converted/./703.wav
# Converting: train/119.wav -> train_converted/./119.wav
# Converting: train/371.wav -> train_converted/./371.wav
# Converting: train/512.wav -> train_converted/./512.wav
# Converting: train/2917.wav -> train_converted/./2917.wav
# Converting: train/1588.wav -> train_converted/./1588.wav
# Converting: train/526.wav -> train_converted/./526.wav
# Converting: train/149.wav -> train_converted/./149.wav
# Converting: train/3030.wav -> train_converted/./3030.wav
# Converting: train/1695.wav -> train_converted/./1695.wav
# Converting: train/3110.wav -> train_converted/./3110.wav
# Converting: train/1245.wav -> train_converted/./1245.wav
# Converting: train/2601.wav -> train_converted/./2601.wav
# Converting: train/1792.wav -> train_converted/./1792.wav
# Converting: train/1717.wav -> train_converted/./1717.wav
# Converting: train/992.wav -> train_converted/./992.wav
# Converting: train/2083.wav -> train_converted/./2083.wav
# Converting: train/1662.wav -> train_converted/./1662.wav
# Converting: train/1369.wav -> train_converted/./1369.wav
# Converting: train/2266.wav -> train_converted/./2266.wav
# Converting: train/458.wav -> train_converted/./458.wav
# Converting: train/1764.wav -> train_converted/./1764.wav
# Converting: train/2062.wav -> train_converted/./2062.wav
# Converting: train/381.wav -> train_converted/./381.wav
# Converting: train/2944.wav -> train_converted/./2944.wav
# Converting: train/2409.wav -> train_converted/./2409.wav
# Converting: train/2315.wav -> train_converted/./2315.wav
# Converting: train/1948.wav -> train_converted/./1948.wav
# Converting: train/1210.wav -> train_converted/./1210.wav
# Converting: train/2620.wav -> train_converted/./2620.wav
# Converting: train/2821.wav -> train_converted/./2821.wav
# Converting: train/743.wav -> train_converted/./743.wav
# Converting: train/291.wav -> train_converted/./291.wav
# Converting: train/1778.wav -> train_converted/./1778.wav
# Converting: train/2678.wav -> train_converted/./2678.wav
# Converting: train/1825.wav -> train_converted/./1825.wav
# Converting: train/2675.wav -> train_converted/./2675.wav
# Converting: train/1333.wav -> train_converted/./1333.wav
# Converting: train/1878.wav -> train_converted/./1878.wav
# Converting: train/688.wav -> train_converted/./688.wav
# Converting: train/1365.wav -> train_converted/./1365.wav
# Converting: train/1850.wav -> train_converted/./1850.wav
# Converting: train/137.wav -> train_converted/./137.wav
# Converting: train/1403.wav -> train_converted/./1403.wav
# Converting: train/108.wav -> train_converted/./108.wav
# Converting: train/147.wav -> train_converted/./147.wav
# Converting: train/687.wav -> train_converted/./687.wav
# Converting: train/813.wav -> train_converted/./813.wav
# Converting: train/133.wav -> train_converted/./133.wav
# Converting: train/2555.wav -> train_converted/./2555.wav
# Converting: train/2333.wav -> train_converted/./2333.wav
# Converting: train/1346.wav -> train_converted/./1346.wav
# Converting: train/1821.wav -> train_converted/./1821.wav
# Converting: train/1867.wav -> train_converted/./1867.wav
# Converting: train/1681.wav -> train_converted/./1681.wav
# Converting: train/3094.wav -> train_converted/./3094.wav
# Converting: train/2278.wav -> train_converted/./2278.wav
# Converting: train/2277.wav -> train_converted/./2277.wav
# Converting: train/1249.wav -> train_converted/./1249.wav
# Converting: train/2218.wav -> train_converted/./2218.wav
# Converting: train/2288.wav -> train_converted/./2288.wav
# Converting: train/1123.wav -> train_converted/./1123.wav
# Converting: train/1089.wav -> train_converted/./1089.wav
# Converting: train/1262.wav -> train_converted/./1262.wav
# Converting: train/2886.wav -> train_converted/./2886.wav
# Converting: train/1915.wav -> train_converted/./1915.wav
# Converting: train/302.wav -> train_converted/./302.wav
# Converting: train/1610.wav -> train_converted/./1610.wav
# Converting: train/852.wav -> train_converted/./852.wav
# Converting: train/2730.wav -> train_converted/./2730.wav
# Converting: train/1045.wav -> train_converted/./1045.wav
# Converting: train/1129.wav -> train_converted/./1129.wav
# Converting: train/2027.wav -> train_converted/./2027.wav
# Converting: train/1437.wav -> train_converted/./1437.wav
# Converting: train/1851.wav -> train_converted/./1851.wav
# Converting: train/2497.wav -> train_converted/./2497.wav
# Converting: train/1586.wav -> train_converted/./1586.wav
# Converting: train/723.wav -> train_converted/./723.wav
# Converting: train/559.wav -> train_converted/./559.wav
# Converting: train/2946.wav -> train_converted/./2946.wav
# Converting: train/1980.wav -> train_converted/./1980.wav
# Converting: train/1640.wav -> train_converted/./1640.wav
# Converting: train/2587.wav -> train_converted/./2587.wav
# Converting: train/2188.wav -> train_converted/./2188.wav
# Converting: train/2100.wav -> train_converted/./2100.wav
# Converting: train/1178.wav -> train_converted/./1178.wav
# Converting: train/2833.wav -> train_converted/./2833.wav
# Converting: train/2056.wav -> train_converted/./2056.wav
# Converting: train/1019.wav -> train_converted/./1019.wav
# Converting: train/2458.wav -> train_converted/./2458.wav
# Converting: train/698.wav -> train_converted/./698.wav
# Converting: train/2903.wav -> train_converted/./2903.wav
# Converting: train/1694.wav -> train_converted/./1694.wav
# Converting: train/1673.wav -> train_converted/./1673.wav
# Converting: train/774.wav -> train_converted/./774.wav
# Converting: train/2087.wav -> train_converted/./2087.wav
# Converting: train/2553.wav -> train_converted/./2553.wav
# Converting: train/95.wav -> train_converted/./95.wav
# Converting: train/430.wav -> train_converted/./430.wav
# Converting: train/1168.wav -> train_converted/./1168.wav
# Converting: train/2800.wav -> train_converted/./2800.wav
# Converting: train/2598.wav -> train_converted/./2598.wav
# Converting: train/565.wav -> train_converted/./565.wav
# Converting: train/2690.wav -> train_converted/./2690.wav
# Converting: train/2444.wav -> train_converted/./2444.wav
# Converting: train/169.wav -> train_converted/./169.wav
# Converting: train/922.wav -> train_converted/./922.wav
# Converting: train/1625.wav -> train_converted/./1625.wav
# Converting: train/802.wav -> train_converted/./802.wav
# Converting: train/982.wav -> train_converted/./982.wav
# Converting: train/908.wav -> train_converted/./908.wav
# Converting: train/1820.wav -> train_converted/./1820.wav
# Converting: train/1875.wav -> train_converted/./1875.wav
# Converting: train/2425.wav -> train_converted/./2425.wav
# Converting: train/1914.wav -> train_converted/./1914.wav
# Converting: train/1181.wav -> train_converted/./1181.wav
# Converting: train/615.wav -> train_converted/./615.wav
# Converting: train/1190.wav -> train_converted/./1190.wav
# Converting: train/1354.wav -> train_converted/./1354.wav
# Converting: train/471.wav -> train_converted/./471.wav
# Converting: train/407.wav -> train_converted/./407.wav
# Converting: train/690.wav -> train_converted/./690.wav
# Converting: train/765.wav -> train_converted/./765.wav
# Converting: train/2050.wav -> train_converted/./2050.wav
# Converting: train/1284.wav -> train_converted/./1284.wav
# Converting: train/1911.wav -> train_converted/./1911.wav
# Converting: train/1921.wav -> train_converted/./1921.wav
# Converting: train/3008.wav -> train_converted/./3008.wav
# Converting: train/378.wav -> train_converted/./378.wav
# Converting: train/832.wav -> train_converted/./832.wav
# Converting: train/3092.wav -> train_converted/./3092.wav
# Converting: train/283.wav -> train_converted/./283.wav
# Converting: train/2468.wav -> train_converted/./2468.wav
# Converting: train/441.wav -> train_converted/./441.wav
# Converting: train/1905.wav -> train_converted/./1905.wav
# Converting: train/2571.wav -> train_converted/./2571.wav
# Converting: train/2784.wav -> train_converted/./2784.wav
# Converting: train/2113.wav -> train_converted/./2113.wav
# Converting: train/2091.wav -> train_converted/./2091.wav
# Converting: train/3049.wav -> train_converted/./3049.wav
# Converting: train/131.wav -> train_converted/./131.wav
# Converting: train/1836.wav -> train_converted/./1836.wav
# Converting: train/2974.wav -> train_converted/./2974.wav
# Converting: train/1738.wav -> train_converted/./1738.wav
# Converting: train/2522.wav -> train_converted/./2522.wav
# Converting: train/2776.wav -> train_converted/./2776.wav
# Converting: train/1897.wav -> train_converted/./1897.wav
# Converting: train/2330.wav -> train_converted/./2330.wav
# Converting: train/763.wav -> train_converted/./763.wav
# Converting: train/443.wav -> train_converted/./443.wav
# Converting: train/450.wav -> train_converted/./450.wav
# Converting: train/3063.wav -> train_converted/./3063.wav
# Converting: train/1264.wav -> train_converted/./1264.wav
# Converting: train/1200.wav -> train_converted/./1200.wav
# Converting: train/2148.wav -> train_converted/./2148.wav
# Converting: train/1811.wav -> train_converted/./1811.wav
# Converting: train/1269.wav -> train_converted/./1269.wav
# Converting: train/1288.wav -> train_converted/./1288.wav
# Converting: train/2516.wav -> train_converted/./2516.wav
# Converting: train/2734.wav -> train_converted/./2734.wav
# Converting: train/3079.wav -> train_converted/./3079.wav
# Converting: train/1201.wav -> train_converted/./1201.wav
# Converting: train/424.wav -> train_converted/./424.wav
# Converting: train/1676.wav -> train_converted/./1676.wav
# Converting: train/826.wav -> train_converted/./826.wav
# Converting: train/2491.wav -> train_converted/./2491.wav
# Converting: train/483.wav -> train_converted/./483.wav
# Converting: train/73.wav -> train_converted/./73.wav
# Converting: train/1501.wav -> train_converted/./1501.wav
# Converting: train/316.wav -> train_converted/./316.wav
# Converting: train/462.wav -> train_converted/./462.wav
# Converting: train/177.wav -> train_converted/./177.wav
# Converting: train/2305.wav -> train_converted/./2305.wav
# Converting: train/1095.wav -> train_converted/./1095.wav
# Converting: train/2130.wav -> train_converted/./2130.wav
# Converting: train/1706.wav -> train_converted/./1706.wav
# Converting: train/83.wav -> train_converted/./83.wav
# Converting: train/2071.wav -> train_converted/./2071.wav
# Converting: train/575.wav -> train_converted/./575.wav
# Converting: train/2201.wav -> train_converted/./2201.wav
# Converting: train/2858.wav -> train_converted/./2858.wav
# Converting: train/2373.wav -> train_converted/./2373.wav
# Converting: train/1922.wav -> train_converted/./1922.wav
# Converting: train/825.wav -> train_converted/./825.wav
# Converting: train/1175.wav -> train_converted/./1175.wav
# Converting: train/2358.wav -> train_converted/./2358.wav
# Converting: train/1446.wav -> train_converted/./1446.wav
# Converting: train/388.wav -> train_converted/./388.wav
# Converting: train/2982.wav -> train_converted/./2982.wav
# Converting: train/2285.wav -> train_converted/./2285.wav
# Converting: train/1392.wav -> train_converted/./1392.wav
# Converting: train/2981.wav -> train_converted/./2981.wav
# Converting: train/1720.wav -> train_converted/./1720.wav
# Converting: train/3058.wav -> train_converted/./3058.wav
# Converting: train/1429.wav -> train_converted/./1429.wav
# Converting: train/980.wav -> train_converted/./980.wav
# Converting: train/2673.wav -> train_converted/./2673.wav
# Converting: train/1578.wav -> train_converted/./1578.wav
# Converting: train/1555.wav -> train_converted/./1555.wav
# Converting: train/882.wav -> train_converted/./882.wav
# Converting: train/1712.wav -> train_converted/./1712.wav
# Converting: train/2644.wav -> train_converted/./2644.wav
# Converting: train/584.wav -> train_converted/./584.wav
# Converting: train/707.wav -> train_converted/./707.wav
# Converting: train/2337.wav -> train_converted/./2337.wav
# Converting: train/2206.wav -> train_converted/./2206.wav
# Converting: train/2270.wav -> train_converted/./2270.wav
# Converting: train/1885.wav -> train_converted/./1885.wav
# Converting: train/1940.wav -> train_converted/./1940.wav
# Converting: train/276.wav -> train_converted/./276.wav
# Converting: train/2664.wav -> train_converted/./2664.wav
# Converting: train/1214.wav -> train_converted/./1214.wav
# Converting: train/984.wav -> train_converted/./984.wav
# Converting: train/2854.wav -> train_converted/./2854.wav
# Converting: train/1471.wav -> train_converted/./1471.wav
# Converting: train/1125.wav -> train_converted/./1125.wav
# Converting: train/2993.wav -> train_converted/./2993.wav
# Converting: train/2029.wav -> train_converted/./2029.wav
# Converting: train/2022.wav -> train_converted/./2022.wav
# Converting: train/959.wav -> train_converted/./959.wav
# Converting: train/1860.wav -> train_converted/./1860.wav
# Converting: train/1073.wav -> train_converted/./1073.wav
# Converting: train/1180.wav -> train_converted/./1180.wav
# Converting: train/2719.wav -> train_converted/./2719.wav
# Converting: train/1339.wav -> train_converted/./1339.wav
# Converting: train/227.wav -> train_converted/./227.wav
# Converting: train/2375.wav -> train_converted/./2375.wav
# Converting: train/1366.wav -> train_converted/./1366.wav
# Converting: train/1859.wav -> train_converted/./1859.wav
# Converting: train/115.wav -> train_converted/./115.wav
# Converting: train/1054.wav -> train_converted/./1054.wav
# Converting: train/2440.wav -> train_converted/./2440.wav
# Converting: train/1884.wav -> train_converted/./1884.wav
# Converting: train/174.wav -> train_converted/./174.wav
# Converting: train/837.wav -> train_converted/./837.wav
# Converting: train/2272.wav -> train_converted/./2272.wav
# Converting: train/453.wav -> train_converted/./453.wav
# Converting: train/158.wav -> train_converted/./158.wav
# Converting: train/196.wav -> train_converted/./196.wav
# Converting: train/2173.wav -> train_converted/./2173.wav
# Converting: train/317.wav -> train_converted/./317.wav
# Converting: train/2436.wav -> train_converted/./2436.wav
# Converting: train/2250.wav -> train_converted/./2250.wav
# Converting: train/795.wav -> train_converted/./795.wav
# Converting: train/2184.wav -> train_converted/./2184.wav
# Converting: train/2873.wav -> train_converted/./2873.wav
# Converting: train/522.wav -> train_converted/./522.wav
# Converting: train/2038.wav -> train_converted/./2038.wav
# Converting: train/2004.wav -> train_converted/./2004.wav
# Converting: train/2559.wav -> train_converted/./2559.wav
# Converting: train/2711.wav -> train_converted/./2711.wav
# Converting: train/2696.wav -> train_converted/./2696.wav
# Converting: train/1303.wav -> train_converted/./1303.wav
# Converting: train/1035.wav -> train_converted/./1035.wav
# Converting: train/1585.wav -> train_converted/./1585.wav
# Converting: train/1237.wav -> train_converted/./1237.wav
# Converting: train/2229.wav -> train_converted/./2229.wav
# Converting: train/2529.wav -> train_converted/./2529.wav
# Converting: train/2505.wav -> train_converted/./2505.wav
# Converting: train/123.wav -> train_converted/./123.wav
# Converting: train/267.wav -> train_converted/./267.wav
# Converting: train/24.wav -> train_converted/./24.wav
# Converting: train/2726.wav -> train_converted/./2726.wav
# Converting: train/2368.wav -> train_converted/./2368.wav
# Converting: train/1530.wav -> train_converted/./1530.wav
# Converting: train/1747.wav -> train_converted/./1747.wav
# Converting: train/1140.wav -> train_converted/./1140.wav
# Converting: train/737.wav -> train_converted/./737.wav
# Converting: train/285.wav -> train_converted/./285.wav
# Converting: train/2204.wav -> train_converted/./2204.wav
# Converting: train/2518.wav -> train_converted/./2518.wav
# Converting: train/1983.wav -> train_converted/./1983.wav
# Converting: train/1643.wav -> train_converted/./1643.wav
# Converting: train/865.wav -> train_converted/./865.wav
# Converting: train/771.wav -> train_converted/./771.wav
# Converting: train/2818.wav -> train_converted/./2818.wav
# Converting: train/1703.wav -> train_converted/./1703.wav
# Converting: train/402.wav -> train_converted/./402.wav
# Converting: train/1233.wav -> train_converted/./1233.wav
# Converting: train/448.wav -> train_converted/./448.wav
# Converting: train/2298.wav -> train_converted/./2298.wav
# Converting: train/1040.wav -> train_converted/./1040.wav
# Converting: train/417.wav -> train_converted/./417.wav
# Converting: train/2311.wav -> train_converted/./2311.wav
# Converting: train/894.wav -> train_converted/./894.wav
# Converting: train/1978.wav -> train_converted/./1978.wav
# Converting: train/1781.wav -> train_converted/./1781.wav
# Converting: train/776.wav -> train_converted/./776.wav
# Converting: train/1468.wav -> train_converted/./1468.wav
# Converting: train/143.wav -> train_converted/./143.wav
# Converting: train/1305.wav -> train_converted/./1305.wav
# Converting: train/1769.wav -> train_converted/./1769.wav
# Converting: train/658.wav -> train_converted/./658.wav
# Converting: train/2018.wav -> train_converted/./2018.wav
# Converting: train/1657.wav -> train_converted/./1657.wav
# Converting: train/2767.wav -> train_converted/./2767.wav
# Converting: train/542.wav -> train_converted/./542.wav
# Converting: train/668.wav -> train_converted/./668.wav
# Converting: train/1880.wav -> train_converted/./1880.wav
# Converting: train/228.wav -> train_converted/./228.wav
# Converting: train/1144.wav -> train_converted/./1144.wav
# Converting: train/1984.wav -> train_converted/./1984.wav
# Converting: train/452.wav -> train_converted/./452.wav
# Converting: train/1452.wav -> train_converted/./1452.wav
# Converting: train/1644.wav -> train_converted/./1644.wav
# Converting: train/547.wav -> train_converted/./547.wav
# Converting: train/1810.wav -> train_converted/./1810.wav
# Converting: train/3061.wav -> train_converted/./3061.wav
# Converting: train/385.wav -> train_converted/./385.wav
# Converting: train/3068.wav -> train_converted/./3068.wav
# Converting: train/384.wav -> train_converted/./384.wav
# Converting: train/3117.wav -> train_converted/./3117.wav
# Converting: train/2714.wav -> train_converted/./2714.wav
# Converting: train/1022.wav -> train_converted/./1022.wav
# Converting: train/1581.wav -> train_converted/./1581.wav
# Converting: train/864.wav -> train_converted/./864.wav
# Converting: train/905.wav -> train_converted/./905.wav
# Converting: train/1174.wav -> train_converted/./1174.wav
# Converting: train/2381.wav -> train_converted/./2381.wav
# Converting: train/1572.wav -> train_converted/./1572.wav
# Converting: train/365.wav -> train_converted/./365.wav
# Converting: train/561.wav -> train_converted/./561.wav
# Converting: train/2738.wav -> train_converted/./2738.wav
# Converting: train/2423.wav -> train_converted/./2423.wav
# Converting: train/1727.wav -> train_converted/./1727.wav
# Converting: train/1173.wav -> train_converted/./1173.wav
# Converting: train/3103.wav -> train_converted/./3103.wav
# Converting: train/2236.wav -> train_converted/./2236.wav
# Converting: train/1782.wav -> train_converted/./1782.wav
# Converting: train/2152.wav -> train_converted/./2152.wav
# Converting: train/677.wav -> train_converted/./677.wav
# Converting: train/1254.wav -> train_converted/./1254.wav
# Converting: train/71.wav -> train_converted/./71.wav
# Converting: train/1202.wav -> train_converted/./1202.wav
# Converting: train/1716.wav -> train_converted/./1716.wav
# Converting: train/669.wav -> train_converted/./669.wav
# Converting: train/1195.wav -> train_converted/./1195.wav
# Converting: train/3015.wav -> train_converted/./3015.wav
# Converting: train/242.wav -> train_converted/./242.wav
# Converting: train/956.wav -> train_converted/./956.wav
# Converting: train/2878.wav -> train_converted/./2878.wav
# Converting: train/1094.wav -> train_converted/./1094.wav
# Converting: train/845.wav -> train_converted/./845.wav
# Converting: train/804.wav -> train_converted/./804.wav
# Converting: train/2028.wav -> train_converted/./2028.wav
# Converting: train/1389.wav -> train_converted/./1389.wav
# Converting: train/395.wav -> train_converted/./395.wav
# Converting: train/54.wav -> train_converted/./54.wav
# Converting: train/1842.wav -> train_converted/./1842.wav
# Converting: train/947.wav -> train_converted/./947.wav
# Converting: train/721.wav -> train_converted/./721.wav
# Converting: train/976.wav -> train_converted/./976.wav
# Converting: train/1220.wav -> train_converted/./1220.wav
# Converting: train/2857.wav -> train_converted/./2857.wav
# Converting: train/2400.wav -> train_converted/./2400.wav
# Converting: train/1154.wav -> train_converted/./1154.wav
# Converting: train/2868.wav -> train_converted/./2868.wav
# Converting: train/1529.wav -> train_converted/./1529.wav
# Converting: train/2577.wav -> train_converted/./2577.wav
# Converting: train/155.wav -> train_converted/./155.wav
# Converting: train/419.wav -> train_converted/./419.wav
# Converting: train/1508.wav -> train_converted/./1508.wav
# Converting: train/2995.wav -> train_converted/./2995.wav
# Converting: train/1711.wav -> train_converted/./1711.wav
# Converting: train/3096.wav -> train_converted/./3096.wav
# Converting: train/2107.wav -> train_converted/./2107.wav
# Converting: train/1906.wav -> train_converted/./1906.wav
# Converting: train/2364.wav -> train_converted/./2364.wav
# Converting: train/996.wav -> train_converted/./996.wav
# Converting: train/1554.wav -> train_converted/./1554.wav
# Converting: train/239.wav -> train_converted/./239.wav
# Converting: train/1749.wav -> train_converted/./1749.wav
# Converting: train/2652.wav -> train_converted/./2652.wav
# Converting: train/1926.wav -> train_converted/./1926.wav
# Converting: train/350.wav -> train_converted/./350.wav
# Converting: train/1042.wav -> train_converted/./1042.wav
# Converting: train/2296.wav -> train_converted/./2296.wav
# Converting: train/1925.wav -> train_converted/./1925.wav
# Converting: train/1368.wav -> train_converted/./1368.wav
# Converting: train/121.wav -> train_converted/./121.wav
# Converting: train/2919.wav -> train_converted/./2919.wav
# Converting: train/1328.wav -> train_converted/./1328.wav
# Converting: train/1083.wav -> train_converted/./1083.wav
# Converting: train/3013.wav -> train_converted/./3013.wav
# Converting: train/2115.wav -> train_converted/./2115.wav
# Converting: train/1379.wav -> train_converted/./1379.wav
# Converting: train/2552.wav -> train_converted/./2552.wav
# Converting: train/2267.wav -> train_converted/./2267.wav
# Converting: train/1869.wav -> train_converted/./1869.wav
# Converting: train/1378.wav -> train_converted/./1378.wav
# Converting: train/2809.wav -> train_converted/./2809.wav
# Converting: train/1756.wav -> train_converted/./1756.wav
# Converting: train/1559.wav -> train_converted/./1559.wav
# Converting: train/3038.wav -> train_converted/./3038.wav
# Converting: train/431.wav -> train_converted/./431.wav
# Converting: train/273.wav -> train_converted/./273.wav
# Converting: train/2026.wav -> train_converted/./2026.wav
# Converting: train/1399.wav -> train_converted/./1399.wav
# Converting: train/2387.wav -> train_converted/./2387.wav
# Converting: train/457.wav -> train_converted/./457.wav
# Converting: train/477.wav -> train_converted/./477.wav
# Converting: train/1387.wav -> train_converted/./1387.wav
# Converting: train/2031.wav -> train_converted/./2031.wav
# Converting: train/497.wav -> train_converted/./497.wav
# Converting: train/2949.wav -> train_converted/./2949.wav
# Converting: train/2289.wav -> train_converted/./2289.wav
# Converting: train/3093.wav -> train_converted/./3093.wav
# Converting: train/1679.wav -> train_converted/./1679.wav
# Converting: train/2457.wav -> train_converted/./2457.wav
# Converting: train/759.wav -> train_converted/./759.wav
# Converting: train/2490.wav -> train_converted/./2490.wav
# Converting: train/1402.wav -> train_converted/./1402.wav
# Converting: train/1029.wav -> train_converted/./1029.wav
# Converting: train/70.wav -> train_converted/./70.wav
# Converting: train/2984.wav -> train_converted/./2984.wav
# Converting: train/1278.wav -> train_converted/./1278.wav
# Converting: train/1988.wav -> train_converted/./1988.wav
# Converting: train/157.wav -> train_converted/./157.wav
# Converting: train/1951.wav -> train_converted/./1951.wav
# Converting: train/2869.wav -> train_converted/./2869.wav
# Converting: train/474.wav -> train_converted/./474.wav
# Converting: train/810.wav -> train_converted/./810.wav
# Converting: train/2683.wav -> train_converted/./2683.wav
# Converting: train/1840.wav -> train_converted/./1840.wav
# Converting: train/920.wav -> train_converted/./920.wav
# Converting: train/1343.wav -> train_converted/./1343.wav
# Converting: train/519.wav -> train_converted/./519.wav
# Converting: train/2727.wav -> train_converted/./2727.wav
# Converting: train/3074.wav -> train_converted/./3074.wav
# Converting: train/1526.wav -> train_converted/./1526.wav
# Converting: train/422.wav -> train_converted/./422.wav
# Converting: train/1883.wav -> train_converted/./1883.wav
# Converting: train/1186.wav -> train_converted/./1186.wav
# Converting: train/2923.wav -> train_converted/./2923.wav
# Converting: train/1450.wav -> train_converted/./1450.wav
# Converting: train/96.wav -> train_converted/./96.wav
# Converting: train/2834.wav -> train_converted/./2834.wav
# Converting: train/2164.wav -> train_converted/./2164.wav
# Converting: train/2680.wav -> train_converted/./2680.wav
# Converting: train/2034.wav -> train_converted/./2034.wav
# Converting: train/1527.wav -> train_converted/./1527.wav
# Converting: train/297.wav -> train_converted/./297.wav
# Converting: train/124.wav -> train_converted/./124.wav
# Converting: train/1161.wav -> train_converted/./1161.wav
# Converting: train/2226.wav -> train_converted/./2226.wav
# Converting: train/2731.wav -> train_converted/./2731.wav
# Converting: train/1283.wav -> train_converted/./1283.wav
# Converting: train/1488.wav -> train_converted/./1488.wav
# Converting: train/1011.wav -> train_converted/./1011.wav
# Converting: train/2792.wav -> train_converted/./2792.wav
# Converting: train/362.wav -> train_converted/./362.wav
# Converting: train/500.wav -> train_converted/./500.wav
# Converting: train/2634.wav -> train_converted/./2634.wav
# Converting: train/2137.wav -> train_converted/./2137.wav
# Converting: train/1476.wav -> train_converted/./1476.wav
# Converting: train/521.wav -> train_converted/./521.wav
# Converting: train/693.wav -> train_converted/./693.wav
# Converting: train/1292.wav -> train_converted/./1292.wav
# Converting: train/663.wav -> train_converted/./663.wav
# Converting: train/2380.wav -> train_converted/./2380.wav
# Converting: train/2470.wav -> train_converted/./2470.wav
# Converting: train/1562.wav -> train_converted/./1562.wav
# Converting: train/2632.wav -> train_converted/./2632.wav
# Converting: train/633.wav -> train_converted/./633.wav
# Converting: train/914.wav -> train_converted/./914.wav
# Converting: train/245.wav -> train_converted/./245.wav
# Converting: train/1103.wav -> train_converted/./1103.wav
# Converting: train/3078.wav -> train_converted/./3078.wav
# Converting: train/997.wav -> train_converted/./997.wav
# Converting: train/2495.wav -> train_converted/./2495.wav
# Converting: train/1295.wav -> train_converted/./1295.wav
# Converting: train/2109.wav -> train_converted/./2109.wav
# Converting: train/631.wav -> train_converted/./631.wav
# Converting: train/2488.wav -> train_converted/./2488.wav
# Converting: train/1639.wav -> train_converted/./1639.wav
# Converting: train/2494.wav -> train_converted/./2494.wav
# Converting: train/756.wav -> train_converted/./756.wav
# Converting: train/235.wav -> train_converted/./235.wav
# Converting: train/632.wav -> train_converted/./632.wav
# Converting: train/2340.wav -> train_converted/./2340.wav
# Converting: train/541.wav -> train_converted/./541.wav
# Converting: train/478.wav -> train_converted/./478.wav
# Converting: train/555.wav -> train_converted/./555.wav
# Converting: train/2893.wav -> train_converted/./2893.wav
# Converting: train/1896.wav -> train_converted/./1896.wav
# Converting: train/608.wav -> train_converted/./608.wav
# Converting: train/1545.wav -> train_converted/./1545.wav
# Converting: train/667.wav -> train_converted/./667.wav
# Converting: train/2862.wav -> train_converted/./2862.wav
# Converting: train/112.wav -> train_converted/./112.wav
# Converting: train/969.wav -> train_converted/./969.wav
# Converting: train/213.wav -> train_converted/./213.wav
# Converting: train/1499.wav -> train_converted/./1499.wav
# Converting: train/61.wav -> train_converted/./61.wav
# Converting: train/520.wav -> train_converted/./520.wav
# Converting: train/13.wav -> train_converted/./13.wav
# Converting: train/2108.wav -> train_converted/./2108.wav
# Converting: train/846.wav -> train_converted/./846.wav
# Converting: train/2959.wav -> train_converted/./2959.wav
# Converting: train/2568.wav -> train_converted/./2568.wav
# Converting: train/2880.wav -> train_converted/./2880.wav
# Converting: train/2728.wav -> train_converted/./2728.wav
# Converting: train/400.wav -> train_converted/./400.wav
# Converting: train/2383.wav -> train_converted/./2383.wav
# Converting: train/1326.wav -> train_converted/./1326.wav
# Converting: train/653.wav -> train_converted/./653.wav
# Converting: train/246.wav -> train_converted/./246.wav
# Converting: train/2261.wav -> train_converted/./2261.wav
# Converting: train/2096.wav -> train_converted/./2096.wav
# Converting: train/1953.wav -> train_converted/./1953.wav
# Converting: train/2770.wav -> train_converted/./2770.wav
# Converting: train/1874.wav -> train_converted/./1874.wav
# Converting: train/1128.wav -> train_converted/./1128.wav
# Converting: train/2979.wav -> train_converted/./2979.wav
# Converting: train/87.wav -> train_converted/./87.wav
# Converting: train/1120.wav -> train_converted/./1120.wav
# Converting: train/1594.wav -> train_converted/./1594.wav
# Converting: train/1686.wav -> train_converted/./1686.wav
# Converting: train/1451.wav -> train_converted/./1451.wav
# Converting: train/3046.wav -> train_converted/./3046.wav
# Converting: train/1981.wav -> train_converted/./1981.wav
# Converting: train/1873.wav -> train_converted/./1873.wav
# Converting: train/1917.wav -> train_converted/./1917.wav
# Converting: train/1138.wav -> train_converted/./1138.wav
# Converting: train/2631.wav -> train_converted/./2631.wav
# Converting: train/2328.wav -> train_converted/./2328.wav
# Converting: train/145.wav -> train_converted/./145.wav
# Converting: train/2055.wav -> train_converted/./2055.wav
# Converting: train/1272.wav -> train_converted/./1272.wav
# Converting: train/1815.wav -> train_converted/./1815.wav
# Converting: train/1130.wav -> train_converted/./1130.wav
# Converting: train/427.wav -> train_converted/./427.wav
# Converting: train/1773.wav -> train_converted/./1773.wav
# Converting: train/2623.wav -> train_converted/./2623.wav
# Converting: train/705.wav -> train_converted/./705.wav
# Converting: train/1147.wav -> train_converted/./1147.wav
# Converting: train/1623.wav -> train_converted/./1623.wav
# Converting: train/2583.wav -> train_converted/./2583.wav
# Converting: train/51.wav -> train_converted/./51.wav
# Converting: train/2934.wav -> train_converted/./2934.wav
# Converting: train/2090.wav -> train_converted/./2090.wav
# Converting: train/1709.wav -> train_converted/./1709.wav
# Converting: train/2017.wav -> train_converted/./2017.wav
# Converting: train/399.wav -> train_converted/./399.wav
# Converting: train/1145.wav -> train_converted/./1145.wav
# Converting: train/84.wav -> train_converted/./84.wav
# Converting: train/57.wav -> train_converted/./57.wav
# Converting: train/1148.wav -> train_converted/./1148.wav
# Converting: train/972.wav -> train_converted/./972.wav
# Converting: train/659.wav -> train_converted/./659.wav
# Converting: train/1762.wav -> train_converted/./1762.wav
# Converting: train/2585.wav -> train_converted/./2585.wav
# Converting: train/463.wav -> train_converted/./463.wav
# Converting: train/1553.wav -> train_converted/./1553.wav
# Converting: train/618.wav -> train_converted/./618.wav
# Converting: train/1411.wav -> train_converted/./1411.wav
# Converting: train/2649.wav -> train_converted/./2649.wav
# Converting: train/1647.wav -> train_converted/./1647.wav
# Converting: train/347.wav -> train_converted/./347.wav
# Converting: train/1232.wav -> train_converted/./1232.wav
# Converting: train/818.wav -> train_converted/./818.wav
# Converting: train/2275.wav -> train_converted/./2275.wav
# Converting: train/79.wav -> train_converted/./79.wav
# Converting: train/1457.wav -> train_converted/./1457.wav
# Converting: train/1336.wav -> train_converted/./1336.wav
# Converting: train/1150.wav -> train_converted/./1150.wav
# Converting: train/1104.wav -> train_converted/./1104.wav
# Converting: train/411.wav -> train_converted/./411.wav
# Converting: train/2757.wav -> train_converted/./2757.wav
# Converting: train/536.wav -> train_converted/./536.wav
# Converting: train/1927.wav -> train_converted/./1927.wav
# Converting: train/3031.wav -> train_converted/./3031.wav
# Converting: train/2956.wav -> train_converted/./2956.wav
# Converting: train/1082.wav -> train_converted/./1082.wav
# Converting: train/902.wav -> train_converted/./902.wav
# Converting: train/1106.wav -> train_converted/./1106.wav
# Converting: train/3055.wav -> train_converted/./3055.wav
# Converting: train/1761.wav -> train_converted/./1761.wav
# Converting: train/2901.wav -> train_converted/./2901.wav
# Converting: train/1737.wav -> train_converted/./1737.wav
# Converting: train/2643.wav -> train_converted/./2643.wav
# Converting: train/2511.wav -> train_converted/./2511.wav
# Converting: train/2303.wav -> train_converted/./2303.wav
# Converting: train/2885.wav -> train_converted/./2885.wav
# Converting: train/271.wav -> train_converted/./271.wav
# Converting: train/1213.wav -> train_converted/./1213.wav
# Converting: train/2133.wav -> train_converted/./2133.wav
# Converting: train/2195.wav -> train_converted/./2195.wav
# Converting: train/2441.wav -> train_converted/./2441.wav
# Converting: train/697.wav -> train_converted/./697.wav
# Converting: train/2847.wav -> train_converted/./2847.wav
# Converting: train/1809.wav -> train_converted/./1809.wav
# Converting: train/1352.wav -> train_converted/./1352.wav
# Converting: train/716.wav -> train_converted/./716.wav
# Converting: train/503.wav -> train_converted/./503.wav
# Converting: train/1909.wav -> train_converted/./1909.wav
# Converting: train/2334.wav -> train_converted/./2334.wav
# Converting: train/2181.wav -> train_converted/./2181.wav
# Converting: train/1541.wav -> train_converted/./1541.wav
# Converting: train/601.wav -> train_converted/./601.wav
# Converting: train/2546.wav -> train_converted/./2546.wav
# Converting: train/179.wav -> train_converted/./179.wav
# Converting: train/144.wav -> train_converted/./144.wav
# Converting: train/141.wav -> train_converted/./141.wav
# Converting: train/1030.wav -> train_converted/./1030.wav
# Converting: train/1692.wav -> train_converted/./1692.wav
# Converting: train/1649.wav -> train_converted/./1649.wav
# Converting: train/3066.wav -> train_converted/./3066.wav
# Converting: train/1235.wav -> train_converted/./1235.wav
# Converting: train/1771.wav -> train_converted/./1771.wav
# Converting: train/1017.wav -> train_converted/./1017.wav
# Converting: train/692.wav -> train_converted/./692.wav
# Converting: train/89.wav -> train_converted/./89.wav
# Converting: train/466.wav -> train_converted/./466.wav
# Converting: train/770.wav -> train_converted/./770.wav
# Converting: train/3009.wav -> train_converted/./3009.wav
# Converting: train/2779.wav -> train_converted/./2779.wav
# Converting: train/1176.wav -> train_converted/./1176.wav
# Converting: train/336.wav -> train_converted/./336.wav
# Converting: train/2627.wav -> train_converted/./2627.wav
# Converting: train/731.wav -> train_converted/./731.wav
# Converting: train/2020.wav -> train_converted/./2020.wav
# Converting: train/1442.wav -> train_converted/./1442.wav
# Converting: train/2430.wav -> train_converted/./2430.wav
# Converting: train/2936.wav -> train_converted/./2936.wav
# Converting: train/2864.wav -> train_converted/./2864.wav
# Converting: train/2403.wav -> train_converted/./2403.wav
# Converting: train/1989.wav -> train_converted/./1989.wav
# Converting: train/1719.wav -> train_converted/./1719.wav
# Converting: train/2596.wav -> train_converted/./2596.wav
# Converting: train/617.wav -> train_converted/./617.wav
# Converting: train/31.wav -> train_converted/./31.wav
# Converting: train/1307.wav -> train_converted/./1307.wav
# Converting: train/515.wav -> train_converted/./515.wav
# Converting: train/1100.wav -> train_converted/./1100.wav
# Converting: train/564.wav -> train_converted/./564.wav
# Converting: train/2855.wav -> train_converted/./2855.wav
# Converting: train/931.wav -> train_converted/./931.wav
# Converting: train/571.wav -> train_converted/./571.wav
# Converting: train/275.wav -> train_converted/./275.wav
# Converting: train/409.wav -> train_converted/./409.wav
# Converting: train/1371.wav -> train_converted/./1371.wav
# Converting: train/3006.wav -> train_converted/./3006.wav
# Converting: train/1652.wav -> train_converted/./1652.wav
# Converting: train/2388.wav -> train_converted/./2388.wav
# Converting: train/2561.wav -> train_converted/./2561.wav
# Converting: train/320.wav -> train_converted/./320.wav
# Converting: train/2810.wav -> train_converted/./2810.wav
# Converting: train/212.wav -> train_converted/./212.wav
# Converting: train/1683.wav -> train_converted/./1683.wav
# Converting: train/2247.wav -> train_converted/./2247.wav
# Converting: train/2339.wav -> train_converted/./2339.wav
# Converting: train/2952.wav -> train_converted/./2952.wav
# Converting: train/2437.wav -> train_converted/./2437.wav
# Converting: train/1152.wav -> train_converted/./1152.wav
# Converting: train/1137.wav -> train_converted/./1137.wav
# Converting: train/1511.wav -> train_converted/./1511.wav
# Converting: train/379.wav -> train_converted/./379.wav
# Converting: train/2412.wav -> train_converted/./2412.wav
# Converting: train/1107.wav -> train_converted/./1107.wav
# Converting: train/2040.wav -> train_converted/./2040.wav
# Converting: train/1715.wav -> train_converted/./1715.wav
# Converting: train/1481.wav -> train_converted/./1481.wav
# Converting: train/1865.wav -> train_converted/./1865.wav
# Converting: train/1938.wav -> train_converted/./1938.wav
# Converting: train/2580.wav -> train_converted/./2580.wav
# Converting: train/734.wav -> train_converted/./734.wav
# Converting: train/578.wav -> train_converted/./578.wav
# Converting: train/2197.wav -> train_converted/./2197.wav
# Converting: train/2785.wav -> train_converted/./2785.wav
# Converting: train/1528.wav -> train_converted/./1528.wav
# Converting: train/2657.wav -> train_converted/./2657.wav
# Converting: train/15.wav -> train_converted/./15.wav
# Converting: train/2023.wav -> train_converted/./2023.wav
# Converting: train/1693.wav -> train_converted/./1693.wav
# Converting: train/2549.wav -> train_converted/./2549.wav
# Converting: train/2539.wav -> train_converted/./2539.wav
# Converting: train/1794.wav -> train_converted/./1794.wav
# Converting: train/1069.wav -> train_converted/./1069.wav
# Converting: train/1868.wav -> train_converted/./1868.wav
# Converting: train/1485.wav -> train_converted/./1485.wav
# Converting: train/722.wav -> train_converted/./722.wav
# Converting: train/594.wav -> train_converted/./594.wav
# Converting: train/223.wav -> train_converted/./223.wav
# Converting: train/2621.wav -> train_converted/./2621.wav
# Converting: train/307.wav -> train_converted/./307.wav
# Converting: train/1994.wav -> train_converted/./1994.wav
# Converting: train/2072.wav -> train_converted/./2072.wav
# Converting: train/437.wav -> train_converted/./437.wav
# Converting: train/1340.wav -> train_converted/./1340.wav
# Converting: train/2189.wav -> train_converted/./2189.wav
# Converting: train/14.wav -> train_converted/./14.wav
# Converting: train/1619.wav -> train_converted/./1619.wav
# Converting: train/2294.wav -> train_converted/./2294.wav
# Converting: train/1680.wav -> train_converted/./1680.wav
# Converting: train/1816.wav -> train_converted/./1816.wav
# Converting: train/2932.wav -> train_converted/./2932.wav
# Converting: train/1967.wav -> train_converted/./1967.wav
# Converting: train/156.wav -> train_converted/./156.wav
# Converting: train/1800.wav -> train_converted/./1800.wav
# Converting: train/356.wav -> train_converted/./356.wav
# Converting: train/1167.wav -> train_converted/./1167.wav
# Converting: train/2906.wav -> train_converted/./2906.wav
# Converting: train/1111.wav -> train_converted/./1111.wav
# Converting: train/2393.wav -> train_converted/./2393.wav
# Converting: train/1454.wav -> train_converted/./1454.wav
# Converting: train/2717.wav -> train_converted/./2717.wav
# Converting: train/2357.wav -> train_converted/./2357.wav
# Converting: train/913.wav -> train_converted/./913.wav
# Converting: train/2443.wav -> train_converted/./2443.wav
# Converting: train/545.wav -> train_converted/./545.wav
# Converting: train/380.wav -> train_converted/./380.wav
# Converting: train/1798.wav -> train_converted/./1798.wav
# Converting: train/1393.wav -> train_converted/./1393.wav
# Converting: train/3098.wav -> train_converted/./3098.wav
# Converting: train/66.wav -> train_converted/./66.wav
# Converting: train/938.wav -> train_converted/./938.wav
# Converting: train/2452.wav -> train_converted/./2452.wav
# Converting: train/2068.wav -> train_converted/./2068.wav
# Converting: train/1440.wav -> train_converted/./1440.wav
# Converting: train/8.wav -> train_converted/./8.wav
# Converting: train/2479.wav -> train_converted/./2479.wav
# Converting: train/2760.wav -> train_converted/./2760.wav
# ...
# Converting: test/24.wav -> test_converted/./24.wav
# Converting: test/285.wav -> test_converted/./285.wav
# Converting: test/143.wav -> test_converted/./143.wav
# Converting: test/228.wav -> test_converted/./228.wav
# Converting: test/71.wav -> test_converted/./71.wav
# Converting: test/242.wav -> test_converted/./242.wav
# Converting: test/54.wav -> test_converted/./54.wav
# Converting: test/155.wav -> test_converted/./155.wav
# Converting: test/239.wav -> test_converted/./239.wav
# Converting: test/121.wav -> test_converted/./121.wav
# Converting: test/273.wav -> test_converted/./273.wav
# Converting: test/70.wav -> test_converted/./70.wav
# Converting: test/157.wav -> test_converted/./157.wav
# Converting: test/96.wav -> test_converted/./96.wav
# Converting: test/297.wav -> test_converted/./297.wav
# Converting: test/124.wav -> test_converted/./124.wav
# Converting: test/245.wav -> test_converted/./245.wav
# Converting: test/235.wav -> test_converted/./235.wav
# Converting: test/112.wav -> test_converted/./112.wav
# Converting: test/213.wav -> test_converted/./213.wav
# Converting: test/61.wav -> test_converted/./61.wav
# Converting: test/13.wav -> test_converted/./13.wav
# Converting: test/246.wav -> test_converted/./246.wav
# Converting: test/87.wav -> test_converted/./87.wav
# Converting: test/145.wav -> test_converted/./145.wav
# Converting: test/51.wav -> test_converted/./51.wav
# Converting: test/84.wav -> test_converted/./84.wav
# Converting: test/57.wav -> test_converted/./57.wav
# Converting: test/79.wav -> test_converted/./79.wav
# Converting: test/271.wav -> test_converted/./271.wav
# Converting: test/179.wav -> test_converted/./179.wav
# Converting: test/144.wav -> test_converted/./144.wav
# Converting: test/141.wav -> test_converted/./141.wav
# Converting: test/89.wav -> test_converted/./89.wav
# Converting: test/336.wav -> test_converted/./336.wav
# Converting: test/31.wav -> test_converted/./31.wav
# Converting: test/275.wav -> test_converted/./275.wav
# Converting: test/320.wav -> test_converted/./320.wav
# Converting: test/212.wav -> test_converted/./212.wav
# Converting: test/15.wav -> test_converted/./15.wav
# Converting: test/223.wav -> test_converted/./223.wav
# Converting: test/307.wav -> test_converted/./307.wav
# Converting: test/14.wav -> test_converted/./14.wav
# Converting: test/156.wav -> test_converted/./156.wav
# Converting: test/66.wav -> test_converted/./66.wav
# Converting: test/8.wav -> test_converted/./8.wav
# Converting: test/151.wav -> test_converted/./151.wav
# Converting: test/67.wav -> test_converted/./67.wav
# Converting: test/63.wav -> test_converted/./63.wav
# Converting: test/277.wav -> test_converted/./277.wav
# Converting: test/132.wav -> test_converted/./132.wav
# Converting: test/114.wav -> test_converted/./114.wav
# Converting: test/166.wav -> test_converted/./166.wav
# Converting: test/134.wav -> test_converted/./134.wav
# Converting: test/146.wav -> test_converted/./146.wav
# Converting: test/254.wav -> test_converted/./254.wav
# Converting: test/128.wav -> test_converted/./128.wav
# Converting: test/33.wav -> test_converted/./33.wav
# Converting: test/56.wav -> test_converted/./56.wav
# Converting: test/300.wav -> test_converted/./300.wav
# Converting: test/304.wav -> test_converted/./304.wav
# Converting: test/117.wav -> test_converted/./117.wav
# Converting: test/125.wav -> test_converted/./125.wav
# Converting: test/109.wav -> test_converted/./109.wav
# Converting: test/120.wav -> test_converted/./120.wav
# Converting: test/312.wav -> test_converted/./312.wav
# Converting: test/164.wav -> test_converted/./164.wav
# Converting: test/173.wav -> test_converted/./173.wav
# Converting: test/116.wav -> test_converted/./116.wav
# Converting: test/220.wav -> test_converted/./220.wav
# Converting: test/2.wav -> test_converted/./2.wav
# Converting: test/332.wav -> test_converted/./332.wav
# Converting: test/150.wav -> test_converted/./150.wav
# Converting: test/252.wav -> test_converted/./252.wav
# Converting: test/286.wav -> test_converted/./286.wav
# Converting: test/27.wav -> test_converted/./27.wav
# Converting: test/1.wav -> test_converted/./1.wav
# Converting: test/49.wav -> test_converted/./49.wav
# Converting: test/287.wav -> test_converted/./287.wav
# Converting: test/210.wav -> test_converted/./210.wav
# Converting: test/309.wav -> test_converted/./309.wav
# Converting: test/154.wav -> test_converted/./154.wav
# Converting: test/122.wav -> test_converted/./122.wav
# Converting: test/30.wav -> test_converted/./30.wav
# Converting: test/207.wav -> test_converted/./207.wav
# Converting: test/23.wav -> test_converted/./23.wav
# Converting: test/200.wav -> test_converted/./200.wav
# Converting: test/269.wav -> test_converted/./269.wav
# Converting: test/266.wav -> test_converted/./266.wav
# Converting: test/314.wav -> test_converted/./314.wav
# Converting: test/68.wav -> test_converted/./68.wav
# Converting: test/218.wav -> test_converted/./218.wav
# Converting: test/90.wav -> test_converted/./90.wav
# Converting: test/263.wav -> test_converted/./263.wav
# Converting: test/129.wav -> test_converted/./129.wav
# Converting: test/42.wav -> test_converted/./42.wav
# Converting: test/136.wav -> test_converted/./136.wav
# Converting: test/175.wav -> test_converted/./175.wav
# Converting: test/55.wav -> test_converted/./55.wav
# Converting: test/290.wav -> test_converted/./290.wav
# Converting: test/78.wav -> test_converted/./78.wav
# Converting: test/64.wav -> test_converted/./64.wav
# Converting: test/342.wav -> test_converted/./342.wav
# Converting: test/172.wav -> test_converted/./172.wav
# Converting: test/74.wav -> test_converted/./74.wav
# Converting: test/107.wav -> test_converted/./107.wav
# Converting: test/341.wav -> test_converted/./341.wav
# Converting: test/268.wav -> test_converted/./268.wav
# Converting: test/85.wav -> test_converted/./85.wav
# Converting: test/5.wav -> test_converted/./5.wav
# Converting: test/299.wav -> test_converted/./299.wav
# Converting: test/3.wav -> test_converted/./3.wav
# Converting: test/294.wav -> test_converted/./294.wav
# Converting: test/180.wav -> test_converted/./180.wav
# Converting: test/279.wav -> test_converted/./279.wav
# Converting: test/194.wav -> test_converted/./194.wav
# Converting: test/52.wav -> test_converted/./52.wav
# Converting: test/62.wav -> test_converted/./62.wav
# Converting: test/298.wav -> test_converted/./298.wav
# Converting: test/211.wav -> test_converted/./211.wav
# Converting: test/238.wav -> test_converted/./238.wav
# Converting: test/261.wav -> test_converted/./261.wav
# Converting: test/250.wav -> test_converted/./250.wav
# Converting: test/274.wav -> test_converted/./274.wav
# Converting: test/163.wav -> test_converted/./163.wav
# Converting: test/80.wav -> test_converted/./80.wav
# Converting: test/168.wav -> test_converted/./168.wav
# Converting: test/186.wav -> test_converted/./186.wav
# Converting: test/92.wav -> test_converted/./92.wav
# Converting: test/221.wav -> test_converted/./221.wav
# Converting: test/191.wav -> test_converted/./191.wav
# Converting: test/215.wav -> test_converted/./215.wav
# Converting: test/39.wav -> test_converted/./39.wav
# Converting: test/93.wav -> test_converted/./93.wav
# Converting: test/303.wav -> test_converted/./303.wav
# Converting: test/152.wav -> test_converted/./152.wav
# Converting: test/11.wav -> test_converted/./11.wav
# Converting: test/183.wav -> test_converted/./183.wav
# Converting: test/289.wav -> test_converted/./289.wav
# Converting: test/12.wav -> test_converted/./12.wav
# Converting: test/60.wav -> test_converted/./60.wav
# Converting: test/36.wav -> test_converted/./36.wav
# Converting: test/189.wav -> test_converted/./189.wav
# Converting: test/295.wav -> test_converted/./295.wav
# Converting: test/102.wav -> test_converted/./102.wav
# Converting: test/305.wav -> test_converted/./305.wav
# Converting: test/140.wav -> test_converted/./140.wav
# Converting: test/216.wav -> test_converted/./216.wav
# Converting: test/318.wav -> test_converted/./318.wav
# Converting: test/201.wav -> test_converted/./201.wav
# Converting: test/46.wav -> test_converted/./46.wav
# Converting: test/53.wav -> test_converted/./53.wav
# Converting: test/322.wav -> test_converted/./322.wav
# Converting: test/288.wav -> test_converted/./288.wav
# Converting: test/264.wav -> test_converted/./264.wav
# Converting: test/319.wav -> test_converted/./319.wav
# Converting: test/244.wav -> test_converted/./244.wav
# Converting: test/75.wav -> test_converted/./75.wav
# Converting: test/296.wav -> test_converted/./296.wav
# Converting: test/219.wav -> test_converted/./219.wav
# Converting: test/255.wav -> test_converted/./255.wav
# Converting: test/17.wav -> test_converted/./17.wav
# Converting: test/21.wav -> test_converted/./21.wav
# Converting: test/203.wav -> test_converted/./203.wav
# Converting: test/327.wav -> test_converted/./327.wav
# Converting: test/171.wav -> test_converted/./171.wav
# Converting: test/76.wav -> test_converted/./76.wav
# Converting: test/199.wav -> test_converted/./199.wav
# Converting: test/105.wav -> test_converted/./105.wav
# Converting: test/126.wav -> test_converted/./126.wav
# Converting: test/20.wav -> test_converted/./20.wav
# Converting: test/281.wav -> test_converted/./281.wav
# Converting: test/222.wav -> test_converted/./222.wav
# Converting: test/104.wav -> test_converted/./104.wav
# Converting: test/197.wav -> test_converted/./197.wav
# Converting: test/249.wav -> test_converted/./249.wav
# Converting: test/230.wav -> test_converted/./230.wav
# Converting: test/98.wav -> test_converted/./98.wav
# Converting: test/167.wav -> test_converted/./167.wav
# Converting: test/308.wav -> test_converted/./308.wav
# Converting: test/344.wav -> test_converted/./344.wav
# Converting: test/47.wav -> test_converted/./47.wav
# Converting: test/232.wav -> test_converted/./232.wav
# Converting: test/190.wav -> test_converted/./190.wav
# Converting: test/139.wav -> test_converted/./139.wav
# Converting: test/25.wav -> test_converted/./25.wav
# Converting: test/323.wav -> test_converted/./323.wav
# Converting: test/188.wav -> test_converted/./188.wav
# Converting: test/202.wav -> test_converted/./202.wav
# Converting: test/72.wav -> test_converted/./72.wav
# Converting: test/37.wav -> test_converted/./37.wav
# Converting: test/293.wav -> test_converted/./293.wav
# Converting: test/59.wav -> test_converted/./59.wav
# Converting: test/343.wav -> test_converted/./343.wav
# Converting: test/338.wav -> test_converted/./338.wav
# Converting: test/251.wav -> test_converted/./251.wav
# Converting: test/135.wav -> test_converted/./135.wav
# Converting: test/247.wav -> test_converted/./247.wav
# Converting: test/306.wav -> test_converted/./306.wav
# Converting: test/178.wav -> test_converted/./178.wav
# Converting: test/337.wav -> test_converted/./337.wav
# Converting: test/310.wav -> test_converted/./310.wav
# Converting: test/38.wav -> test_converted/./38.wav
# Converting: test/311.wav -> test_converted/./311.wav
# Converting: test/326.wav -> test_converted/./326.wav
# Converting: test/225.wav -> test_converted/./225.wav
# Converting: test/97.wav -> test_converted/./97.wav
# Converting: test/313.wav -> test_converted/./313.wav
# Converting: test/234.wav -> test_converted/./234.wav
# Converting: test/280.wav -> test_converted/./280.wav
# Converting: test/82.wav -> test_converted/./82.wav
# Converting: test/193.wav -> test_converted/./193.wav
# Converting: test/110.wav -> test_converted/./110.wav
# Converting: test/81.wav -> test_converted/./81.wav
# Converting: test/40.wav -> test_converted/./40.wav
# Converting: test/205.wav -> test_converted/./205.wav
# Converting: test/127.wav -> test_converted/./127.wav
# Converting: test/103.wav -> test_converted/./103.wav
# Converting: test/240.wav -> test_converted/./240.wav
# Converting: test/101.wav -> test_converted/./101.wav
# Converting: test/45.wav -> test_converted/./45.wav
# Converting: test/187.wav -> test_converted/./187.wav
# Converting: test/106.wav -> test_converted/./106.wav
# Converting: test/253.wav -> test_converted/./253.wav
# Converting: test/333.wav -> test_converted/./333.wav
# Converting: test/204.wav -> test_converted/./204.wav
# Converting: test/48.wav -> test_converted/./48.wav
# Converting: test/22.wav -> test_converted/./22.wav
# Converting: test/236.wav -> test_converted/./236.wav
# Converting: test/258.wav -> test_converted/./258.wav
# Converting: test/339.wav -> test_converted/./339.wav
# Converting: test/160.wav -> test_converted/./160.wav
# Converting: test/182.wav -> test_converted/./182.wav
# Converting: test/325.wav -> test_converted/./325.wav
# Converting: test/10.wav -> test_converted/./10.wav
# Converting: test/331.wav -> test_converted/./331.wav
# Converting: test/9.wav -> test_converted/./9.wav
# Converting: test/292.wav -> test_converted/./292.wav
# Converting: test/100.wav -> test_converted/./100.wav
# Converting: test/265.wav -> test_converted/./265.wav
# Converting: test/94.wav -> test_converted/./94.wav
# Converting: test/113.wav -> test_converted/./113.wav
# Converting: test/99.wav -> test_converted/./99.wav
# Converting: test/65.wav -> test_converted/./65.wav
# Converting: test/334.wav -> test_converted/./334.wav
# Converting: test/330.wav -> test_converted/./330.wav
# Converting: test/206.wav -> test_converted/./206.wav
# Converting: test/118.wav -> test_converted/./118.wav
# Converting: test/170.wav -> test_converted/./170.wav
# Converting: test/256.wav -> test_converted/./256.wav
# Converting: test/335.wav -> test_converted/./335.wav
# Converting: test/315.wav -> test_converted/./315.wav
# Converting: test/259.wav -> test_converted/./259.wav
# Converting: test/272.wav -> test_converted/./272.wav
# Converting: test/50.wav -> test_converted/./50.wav
# Converting: test/19.wav -> test_converted/./19.wav
# Converting: test/69.wav -> test_converted/./69.wav
# Converting: test/324.wav -> test_converted/./324.wav
# Converting: test/77.wav -> test_converted/./77.wav
# Converting: test/233.wav -> test_converted/./233.wav
# Converting: test/321.wav -> test_converted/./321.wav
# Converting: test/192.wav -> test_converted/./192.wav
# Converting: test/229.wav -> test_converted/./229.wav
# Converting: test/16.wav -> test_converted/./16.wav
# Converting: test/328.wav -> test_converted/./328.wav
# Converting: test/142.wav -> test_converted/./142.wav
# Converting: test/91.wav -> test_converted/./91.wav
# Converting: test/29.wav -> test_converted/./29.wav
# Converting: test/195.wav -> test_converted/./195.wav
# Converting: test/282.wav -> test_converted/./282.wav
# Converting: test/162.wav -> test_converted/./162.wav
# Converting: test/231.wav -> test_converted/./231.wav
# Converting: test/34.wav -> test_converted/./34.wav
# Converting: test/224.wav -> test_converted/./224.wav
# Converting: test/237.wav -> test_converted/./237.wav
# Converting: test/41.wav -> test_converted/./41.wav
# Converting: test/257.wav -> test_converted/./257.wav
# Converting: test/111.wav -> test_converted/./111.wav
# Converting: test/345.wav -> test_converted/./345.wav
# Converting: test/159.wav -> test_converted/./159.wav
# Converting: test/214.wav -> test_converted/./214.wav
# Converting: test/226.wav -> test_converted/./226.wav
# Converting: test/184.wav -> test_converted/./184.wav
# Converting: test/198.wav -> test_converted/./198.wav
# Converting: test/43.wav -> test_converted/./43.wav
# Converting: test/346.wav -> test_converted/./346.wav
# Converting: test/7.wav -> test_converted/./7.wav
# Converting: test/28.wav -> test_converted/./28.wav
# Converting: test/26.wav -> test_converted/./26.wav
# Converting: test/208.wav -> test_converted/./208.wav
# Converting: test/329.wav -> test_converted/./329.wav
# Converting: test/284.wav -> test_converted/./284.wav
# Converting: test/301.wav -> test_converted/./301.wav
# Converting: test/248.wav -> test_converted/./248.wav
# Converting: test/58.wav -> test_converted/./58.wav
# Converting: test/130.wav -> test_converted/./130.wav
# Converting: test/86.wav -> test_converted/./86.wav
# Converting: test/241.wav -> test_converted/./241.wav
# Converting: test/88.wav -> test_converted/./88.wav
# Converting: test/153.wav -> test_converted/./153.wav
# Converting: test/262.wav -> test_converted/./262.wav
# Converting: test/176.wav -> test_converted/./176.wav
# Converting: test/35.wav -> test_converted/./35.wav
# Converting: test/243.wav -> test_converted/./243.wav
# Converting: test/217.wav -> test_converted/./217.wav

# %% [markdown]
# 讀取字典檔，建立 台羅拼音->音素 序列的對應表

# %%
import os
import csv
import librosa
import numpy as np
from sklearn.model_selection import train_test_split

def load_lexicon(lexicon_path):
    # lexicon.txt格式假設為：
    # word phone1 phone2 ...
    # 如：ba b a
    # a iNULL a
    # 將每一行的第一個欄位當成拼音字串，其餘欄位是對應音素。
    lex_map = {}
    with open(lexicon_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = line.split()
            # 第一個為詞彙(如"ba")，後面為其對應音素序列
            word = parts[0]
            phones = parts[1:]
            lex_map[word] = phones
    return lex_map

# %% [markdown]
# 將台羅拼音句子轉為音素序列

# %%
def text_to_phoneme_sequence(text, lex_map):
    # text 如："li be e mih kiann lan lan san san long be tsiau tsng"
    # 一般是空白分詞，若需要根據您的實際資料格式調整
    words = text.strip().split()
    
    phoneme_seq = []
    for w in words:
        # 檢查字典中是否有此詞
        # 實務上，有些拼音可能要再細分或檢查
        if w in lex_map:
            phoneme_seq.extend(lex_map[w])
        else:
            # 若無對應，則可考慮略過或保留原文字串
            # 這裡先簡單略過或將 w 作為一整個 token
            # 實務上建議先確保 lexicon 完備
            phoneme_seq.append(w)
    return phoneme_seq

# %% [markdown]
# 對 log_mel_spec 進行時間與頻率維度遮罩

# %%
def spec_augment(log_mel_spec, time_mask_num=1, freq_mask_num=1, time_mask_size=20, freq_mask_size=10):
    # log_mel_spec: shape (n_mels, T)
    n_mels, T = log_mel_spec.shape

    # 頻率遮罩
    for _ in range(freq_mask_num):
        f = np.random.randint(0, freq_mask_size)
        f_start = np.random.randint(0, n_mels - f)
        log_mel_spec[f_start:f_start+f, :] = 0

    # 時間遮罩
    for _ in range(time_mask_num):
        t = np.random.randint(0, time_mask_size)
        t_start = np.random.randint(0, T - t)
        log_mel_spec[:, t_start:t_start+t] = 0

    return log_mel_spec

# %% [markdown]
# 載入音檔並萃取特徵(Mel-spectrogram)

# %%
def load_audio_features(wav_path, sr=16000, n_mels=80, frame_length=0.025, frame_shift=0.01):
    # 載入 wav 音檔
    y, sr = librosa.load(wav_path, sr=sr)
    # 計算 n_fft, hop_length, win_length
    n_fft = int(sr * frame_length)
    hop_length = int(sr * frame_shift)
    win_length = n_fft

    # 計算 Mel-filterbank 特徵
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, 
                                              hop_length=hop_length, 
                                              win_length=win_length, 
                                              n_mels=n_mels, fmin=20, fmax=sr/2)
    # 將能量取log(避免log(0)可加上小量)
    log_mel_spec = np.log(np.maximum(mel_spec, 1e-10))
    return log_mel_spec

# %% [markdown]
# 從 train-toneless.csv 讀取資料，處理成最終 (特徵, 標籤序列)清單

# %%
def preprocess_data(entries, wav_dir, lexicon_map):
    features_list = []
    labels_list = []
    for row in entries:
        utt_id = row['id']
        text = row['text']
        wav_path = os.path.join(wav_dir, utt_id + '.wav')
        if not os.path.exists(wav_path):
            print(f"Warning: {wav_path} not found.")
            continue
        feats = load_audio_features(wav_path)
        phoneme_seq = text_to_phoneme_sequence(text, lexicon_map)
        features_list.append(feats)
        labels_list.append(phoneme_seq)
    return features_list, labels_list

# %% [markdown]
# 資料分割

# %%
if __name__ == "__main__":
    lexicon_path = 'lexicon.txt'
    train_csv_path = 'train-toneless.csv'
    wav_dir = 'train_converted'
    
    # 讀取 lexicon
    lex_map = load_lexicon(lexicon_path)
    
    # 讀取整個訓練 csv
    entries = []
    with open(train_csv_path, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            entries.append(row)
    
    # 分割比例: 90% 用於訓練, 10% 用於驗證
    train_entries, valid_entries = train_test_split(entries, test_size=0.1, random_state=42)
    
    # 前處理訓練集資料
    train_features, train_labels = preprocess_data(train_entries, wav_dir, lex_map)
    # 前處理驗證集資料
    valid_features, valid_labels = preprocess_data(valid_entries, wav_dir, lex_map)
    
    # 建立 phoneme->id 映射表 (根據訓練集和驗證集所有出現過的 phoneme)
    all_phones = set(p for seq in train_labels+valid_labels for p in seq)
    phone2id = {p: i for i, p in enumerate(sorted(all_phones))}
    
    # 將訓練與驗證標籤轉為 ID 序列
    train_labels_id = [[phone2id[p] for p in seq] for seq in train_labels]
    valid_labels_id = [[phone2id[p] for p in seq] for seq in valid_labels]
    
    # 至此您擁有：
    # train_features, train_labels_id
    # valid_features, valid_labels_id
    # 可以進一步用於模型訓練及驗證。

# %% [markdown]
# 訓練模型()

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from tqdm import tqdm

# 假設您已有以下資料 (由前處理階段取得)
# train_features: List of np.array, each shape like (n_mels, T_frames)
# train_labels_id: List of List[int]
# valid_features: same structure as train_features
# valid_labels_id: same structure as train_labels_id
# phone2id: dict {phone_str: id_int}, 且有包含 <blank>:0

class SpeechDataset(Dataset):
    def __init__(self, features_list, labels_list):
        self.features_list = features_list
        self.labels_list = labels_list

    def __len__(self):
        return len(self.features_list)

    def __getitem__(self, idx):
        feat = self.features_list[idx].T  # (T, n_mels)
        label = self.labels_list[idx]
        feat_tensor = torch.tensor(feat, dtype=torch.float32)
        label_tensor = torch.tensor(label, dtype=torch.int64)
        return feat_tensor, label_tensor

def collate_fn(batch):
    feat_lengths = [x[0].shape[0] for x in batch]
    label_lengths = [x[1].shape[0] for x in batch]
    max_feat_len = max(feat_lengths)
    max_label_len = max(label_lengths)

    n_mels = batch[0][0].shape[1]
    feats_padded = torch.zeros(len(batch), max_feat_len, n_mels)
    labels_padded = torch.zeros(len(batch), max_label_len, dtype=torch.int64)

    for i, (f, l) in enumerate(batch):
        feats_padded[i, :f.shape[0], :] = f
        labels_padded[i, :l.shape[0]] = l

    return feats_padded, labels_padded, torch.tensor(feat_lengths, dtype=torch.int64), torch.tensor(label_lengths, dtype=torch.int64)


train_dataset = SpeechDataset(train_features, train_labels_id)
valid_dataset = SpeechDataset(valid_features, valid_labels_id)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn)
valid_loader = DataLoader(valid_dataset, batch_size=8, shuffle=False, collate_fn=collate_fn)


class RNNCTCModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=3):
        super(RNNCTCModel, self).__init__()
        self.rnn = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_dim*2, output_dim)

    def forward(self, x):
        outputs, _ = self.rnn(x) # (batch, T, hidden_dim*2)
        logits = self.fc(outputs) # (batch, T, output_dim)
        logits = logits.permute(1, 0, 2) # (T, batch, output_dim)
        return logits

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

n_mels = train_features[0].shape[0]
output_dim = len(phone2id)
hidden_dim = 256
num_layers = 3

model = RNNCTCModel(input_dim=n_mels, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers).to(device)

criterion = nn.CTCLoss(blank=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0
    total_samples = 0
    pbar = tqdm(dataloader, desc="Training", leave=False)
    for feats, labels, feat_lens, label_lens in pbar:
        feats = feats.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        logits = model(feats) # (T, batch, output_dim)
        log_probs = torch.nn.functional.log_softmax(logits, dim=-1)
        
        loss = criterion(log_probs, labels, feat_lens, label_lens)
        loss.backward()
        optimizer.step()

        batch_size = feats.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size
        pbar.set_postfix(loss=f"{loss.item():.4f}")

    return total_loss / total_samples

def validate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    total_samples = 0
    pbar = tqdm(dataloader, desc="Validating", leave=False)
    with torch.no_grad():
        for feats, labels, feat_lens, label_lens in pbar:
            feats = feats.to(device)
            labels = labels.to(device)

            logits = model(feats)
            log_probs = torch.nn.functional.log_softmax(logits, dim=-1)
            loss = criterion(log_probs, labels, feat_lens, label_lens)

            batch_size = feats.size(0)
            total_loss += loss.item() * batch_size
            total_samples += batch_size
            pbar.set_postfix(val_loss=f"{loss.item():.4f}")

    return total_loss / total_samples

# Early Stopping 機制
class EarlyStopping:
    def __init__(self, patience=3, delta=0.0, save_path="best_model.pth"):
        self.patience = patience
        self.delta = delta
        self.save_path = save_path
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        torch.save(model.state_dict(), self.save_path)

num_epochs = 10
early_stopping = EarlyStopping(patience=50, delta=0.0, save_path="best_model.pth")

for epoch in range(num_epochs):
    print(f"Epoch {epoch+1}/{num_epochs}")
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
    valid_loss = validate(model, valid_loader, criterion, device)
    print(f"Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}")

    # Early Stopping 判斷
    early_stopping(valid_loss, model)
    if early_stopping.early_stop:
        print("Early stopping!")
        break

# 訓練完成後，已經透過 EarlyStopping 儲存最佳模型於 "best_model.pth"
# 若想儲存最後的模型狀態，也可另外 torch.save(model.state_dict(), "final_model.pth")

# %% [markdown]
# 預測測驗集

# %%
import os
import csv
import torch
import torch.nn as nn
import numpy as np
import librosa

# 假設已經有以下變數:
# model: 訓練完成後的 RNNCTCModel，且已載入權重
# device: torch.device
# phone2id: dict {phone_str: id_int}, 並包含 <blank>:0
id2phone = {v: k for k, v in phone2id.items()}

def load_audio_features(wav_path, sr=16000, n_mels=80, frame_length=0.025, frame_shift=0.01):
    y, sr = librosa.load(wav_path, sr=sr)
    n_fft = int(sr * frame_length)
    hop_length = int(sr * frame_shift)
    win_length = n_fft
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft,
                                              hop_length=hop_length,
                                              win_length=win_length,
                                              n_mels=n_mels, fmin=20, fmax=sr/2)
    log_mel_spec = np.log(np.maximum(mel_spec, 1e-10))
    return log_mel_spec

def ctc_greedy_decode(logits, blank_id=0):
    # logits: (T, batch, output_dim)
    # greedy decode
    pred_ids = torch.argmax(logits, dim=-1)  # (T, batch)
    pred_ids = pred_ids.transpose(0,1)       # (batch, T)
    results = []
    for seq in pred_ids:
        prev = blank_id
        out = []
        for p in seq:
            p = p.item()
            if p != blank_id and p != prev:
                out.append(p)
            prev = p
        results.append(out)
    return results

def inference(model, test_wav_dir, sample_csv_path, output_csv_path):
    # sample.csv: 欄位 (id, text)
    # 我們會根據 sample.csv 的 id 讀取 test_converted 目錄下的同名音檔
    # 並將推論結果寫回 output_csv_path
    test_entries = []
    with open(sample_csv_path, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            test_entries.append(row)

    model.eval()
    n_mels = train_features[0].shape[0]  # 假設與訓練時相同的 n_mels

    predictions = []

    with torch.no_grad():
        for entry in test_entries:
            utt_id = entry["id"]
            
            wav_path = os.path.join(test_wav_dir, utt_id + ".wav")
            if not os.path.exists(wav_path):
                print(f"Warning: {wav_path} not found.")
                # 若音檔不存在，可用空結果或略過
                predictions.append({"id": utt_id, "text": ""})
                continue

            feats = load_audio_features(wav_path)
            feats_t = torch.tensor(feats.T, dtype=torch.float32).unsqueeze(0).to(device) # (1, T, n_mels)

            logits = model(feats_t)  # (T, batch, output_dim)
            log_probs = torch.nn.functional.log_softmax(logits, dim=-1)
            pred_ids = ctc_greedy_decode(log_probs, blank_id=0)[0]

            pred_phones = [id2phone[i] for i in pred_ids]
            pred_text = " ".join(pred_phones)

            predictions.append({"id": utt_id, "text": pred_text})

    with open(output_csv_path, 'w', encoding='utf-8', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=["id", "text"])
        writer.writeheader()
        for pred in predictions:
            writer.writerow(pred)

# 假設此時您已載入模型最佳參數:
model.load_state_dict(torch.load("best_model.pth", map_location=device))
model.to(device)

# 執行推論(不計算Levenshtein Distance)
inference(model, "test_converted", "sample.csv", "sample_pred.csv")
